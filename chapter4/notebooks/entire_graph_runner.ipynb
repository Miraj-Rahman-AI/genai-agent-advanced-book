# %%
from src.agent import HelpDeskAgent
from src.configs import Settings
from src.tools.search_xyz_manual import search_xyz_manual
from src.tools.search_xyz_qa import (
 search_xyz_qa,
)

# %%
settings = Settings()

# %%
agent = HelpDeskAgent(
 settings=settings,
 tools=[search_xyz_manual, search_xyz_qa],
)

# %%
question = """
Thank you for your help. 

I am currently considering using the XYZ system and would like your advice on the following two points: 

1. Regarding restrictions on characters that can be used in passwords
When setting a password on this system, could you please provide more information on the range of characters that can be used (e.g., alphanumeric characters, symbols, character length restrictions, etc.)? We would like to confirm the specific specifications to ensure security and prevent authentication errors in the system. 

2. Regarding how to obtain the latest release
We would also appreciate it if you could tell us how to check and obtain the latest update information. 

We apologize for bothering you during your busy schedule, but we would appreciate your assistance. 

"""

question = """
Thank you for your assistance. 

I am currently using the XYZ system and would like your advice on the following points. 

1. How can I limit notifications to specific projects?
I would appreciate it if you could tell me how to limit notifications to specific projects.

2. Regarding restrictions on characters that can be used in passwords.
When setting passwords in this system, could you please provide more information on the range of characters that can be used (e.g., alphanumeric characters, symbols, character length restrictions, etc.)? We would like to confirm the specific specifications to ensure security and prevent authentication errors in the system.

I apologize for bothering you during your busy schedule, but I would appreciate your response. 
"""

# %% [markdown]
# ## Run the entire Help Desk Agent

# %%
result = agent.run_agent(question)

# %%
# Answers
print(result.answer)
