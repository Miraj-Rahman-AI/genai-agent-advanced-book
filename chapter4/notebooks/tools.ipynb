# %% [markdown]
# ## Manual Search Tool

# %%
from src.tools.search_xyz_manual import search_xyz_manual

result = search_xyz_manual.invoke("Online Help Center")
print(result[0].content)

# %%
result

# %% [markdown]
# ## Past Q&A Search Tool

# %%
from src.tools.search_xyz_qa import search_xyz_qa

result = search_xyz_qa.invoke("My account was locked after entering the wrong password")
print(result[0].content)
